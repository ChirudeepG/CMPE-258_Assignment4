# %%
# !pip install nltk
# !pip install gensim
# !pip install transformers
# !pip install sentence-transformers
# !pip install pyLDAvis
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.22.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.10.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 31.4 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 12.1 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.27.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.27.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.13.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.10.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=ae05984242b6947c4554aad468a5e3459ea7024835b051ee87ebd04a86cfb38f
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.97
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.0-py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.10.1)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (4.3.1)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.22.4)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.4.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (67.6.1)
# Collecting funcy
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.4->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.4->pyLDAvis) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->pyLDAvis) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->pyLDAvis) (1.16.0)
# Installing collected packages: funcy, joblib, pyLDAvis
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.2.0 which is incompatible.
# Successfully installed funcy-2.0 joblib-1.2.0 pyLDAvis-3.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (3.5.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (23.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy) (67.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy) (2.1.2)

# %%
# !pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting pyahocorasick
#   Downloading pyahocorasick-2.0.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.4 MB/s eta 0:00:00
# Collecting anyascii
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %%
# !pip install -U pandas-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas-profiling in /usr/local/lib/python3.9/dist-packages (3.2.0)
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.4 MB/s eta 0:00:00
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.1.2-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.9/345.9 kB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (1.10.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (6.0)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (1.4.4)
# Collecting matplotlib<3.7,>=3.2
#   Downloading matplotlib-3.6.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 58.2 MB/s eta 0:00:00
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (0.12.3)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (1.22.4)
# Collecting tqdm<4.65,>=4.48.2
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.0 MB/s eta 0:00:00
# Collecting scipy<1.10,>=1.4.1
#   Downloading scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (0.13.5)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<2.29,>=2.24.0 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling) (2.27.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.9/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (8.4.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (22.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2022.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.9/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.12)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Installing collected packages: typeguard, tqdm, scipy, matplotlib, visions, ydata-profiling, pandas-profiling
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 3.2.0
#     Uninstalling pandas-profiling-3.2.0:
#       Successfully uninstalled pandas-profiling-3.2.0
# Successfully installed matplotlib-3.6.3 pandas-profiling-3.6.6 scipy-1.9.3 tqdm-4.64.1 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.1.2

# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import wordcloud
import nltk
import unicodedata
import contractions
import pickle
import urllib.request
import requests
import spacy
import json
# %matplotlib inline

from bs4 import BeautifulSoup
from bs4.element import Comment
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from collections import defaultdict
from contractions import contractions_dict
from wordcloud import WordCloud, STOPWORDS
from transformers import pipeline

from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem.porter import PorterStemmer
from sentence_transformers import SentenceTransformer, util
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from spacy import displacy

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score

nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('wordnet')
nltk.download('punkt')

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from contractions import contractions_dict
from scipy import stats
from scipy import sparse

import pyLDAvis

# Visualize the topics
pyLDAvis.enable_notebook()

tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
scaler = MinMaxScaler()
std_scaler = StandardScaler()
stops = set(stopword_list)
stemmer = nltk.stem.SnowballStemmer('english')
wordlemmatizer = WordNetLemmatizer()
tokenizer = nltk.word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# **NLP Data. Pick 2 poets, scrape 10 poems each . Put them in a json datastructure and save it under the poets name, in your team drive under folder 'DataSets'**

# %% [markdown]
# **Get Scraped Data**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Mounted at /content/drive

# %%
df_john = pd.read_csv('/content/drive/MyDrive/NLP_ML/john_keats.csv')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_john.drop(columns='Unnamed: 0', inplace=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_john.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           10 non-null     object
#  1   Poem            10 non-null     object
#  2   Poem_for_Human  10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_john.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                            Title  \
# 0                        “Fancy”
# 1  “Ode on a Grecian Urn” (1819)
# 2         “To Lord Byron” (1814)
# 3     “La Belle Dame Sans Merci”
# 4              Ode on Melancholy
#
#                                                 Poem  \
# 0  \nPleasure never is at home:At a touch sweet P...
# 1  Heard melodies are sweet, but those unheardAre...
# 2  Byron! how sweetly sad thy melody! Attuning st...
# 3  O what can ail thee, knight-at-arms,Alone and ...
# 4  No, no, go not to Lethe, neither twistWolf’s-b...
#
#                                       Poem_for_Human
# 0  Ever let the Fancy roam,\nPleasure never is at...
# 1  Heard melodies are sweet, but those unheard\nA...
# 2  Byron! how sweetly sad thy melody!\nAttuning s...
# 3  O what can ail thee, knight-at-arms,Alone and ...
# 4  No, no, go not to Lethe, neither twistWolf’s-b...

# %%
df_alfred = pd.read_csv('/content/drive/MyDrive/NLP_ML/alfred_tennyson.csv')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_alfred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10 non-null     int64
#  1   Title           10 non-null     object
#  2   Poem            10 non-null     object
#  3   Poem_for_Human  9 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_alfred.head()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Unnamed: 0                        Title  \
# 0           0                The BlackBird
# 1           1  The Deadth Of The Old Year
# 2           2                I Entreat You
# 3           3            Crossing The Bar
# 4           4                    The Brook
#
#                                                 Poem  \
# 0  The espaliers and the standards all Are thine;...
# 1  For the old year lies a-dying.Old year you mus...
# 2                Good, but better when you share it.
# 3  Sunset and evening star,And one clear call for...
# 4  I come from haunts of coot and hern,I make a s...
#
#                                       Poem_for_Human
# 0  O blackbird! sing me something well:\nWhile al...
# 1  Full knee-deep lies the winter snow,\nAnd the ...
# 2  I entreat you, Alfred Tennyson,\nCome and shar...
# 3  Sunset and evening star,And one clear call for...
# 4  I come from haunts of coot and hern,I make a s...

# %% [markdown]
# **JSON Conversion**

# %%
result_john = df_john.to_json(orient="index")
parsed = json.loads(result_john)
json.dumps(parsed, indent=4)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '{\n    "0": {\n        "Title": "\\u201cFancy\\u201d",\n        "Poem": "\\nPleasure never is at home:At a touch sweet Pleasure melteth,Like to bubbles when rain pelteth;Then let winged Fancy wanderThrough the thought still spread beyond her:Open wide the mind\\u2019s cage-door,She\\u2019ll dart forth, and cloudward soar.",\n        "Poem_for_Human": "Ever let the Fancy roam,\\nPleasure never is at home:\\nAt a touch sweet Pleasure melteth,\\nLike to bubbles when rain pelteth;\\nThen let winged Fancy wander\\nThrough the thought still spread beyond her:\\nOpen wide the mind\\u2019s cage-door,\\nShe\\u2019ll dart forth, and cloudward soar.\\nO sweet Fancy! let her loose;\\nSummer\\u2019s joys are spoilt by use,\\nAnd the enjoying of the Spring\\nFades as does its blossoming;\\nAutumn\\u2019s red-lipp\\u2019d fruitage too,\\nBlushing through the mist and dew,\\nCloys with tasting: What do then?\\nSit thee by the ingle, when\\nThe sear faggot blazes bright,\\nSpirit of a winter\\u2019s night;\\nWhen the soundless earth is muffled,\\nAnd the caked snow is shuffled"\n    },\n    "1": {\n        "Title": "\\u201cOde on a Grecian Urn\\u201d (1819)",\n        "Poem": "Heard melodies are sweet, but those unheardAre sweeter; therefore, ye soft pipes, play on;Not to the sensual ear, but, more endear\\u2019d,Pipe to the spirit ditties of no tone:\\n\\n",\n        "Poem_for_Human": "Heard melodies are sweet, but those unheard\\nAre sweeter; therefore, ye soft pipes, play on;\\nNot to the sensual ear, but, more endear\\u2019d,\\nPipe to the spirit ditties of no tone:\\nFair youth, beneath the trees, thou canst not leave\\nThy song, nor ever can those trees be bare;\\nBold Lover, never, never canst thou kiss,\\nThough winning near the goal\\u2014yet, do not grieve;\\nShe cannot fade, though thou hast not thy bliss,\\nForever wilt thou love, and she be fair!\\n\\nAh, happy, happy boughs! that cannot shed\\nYour leaves, nor ever bid the Spring adieu;\\nAnd, happy melodist, unwearied,\\nFor ever piping songs for ever new;\\nMore happy love! more happy, happy love!\\nFor ever warm and still to be enjoy\\u2019d,\\nFor ever panting, and for ever young;\\nAll breathing human passion far above,\\nThat leaves a heart high-sorrowful and cloy\\u2019d,\\nA burning forehead, and a parching tongue."\n    },\n    "2": {\n        "Title": "\\u201cTo Lord Byron\\u201d (1814)",\n        "Poem": "Byron! how sweetly sad thy melody! Attuning still the soul to tenderness,As if soft Pity, with unusual stress,Had touch\\u2019d her plaintive lute, and thou, being by,Hadst caught the tones, nor suffer\\u2019d them to die.",\n        "Poem_for_Human": "Byron! how sweetly sad thy melody!\\nAttuning still the soul to tenderness,\\nAs if soft Pity, with unusual stress,\\nHad touch\\u2019d her plaintive lute, and thou, being by,\\nHadst caught the tones, nor suffer\\u2019d them to die.\\nO\\u2019ershadowing sorrow doth not make thee less\\nDelightful: thou thy griefs dost dress\\nWith a bright halo, shining beamily,\\nAs when a cloud the golden moon doth veil,\\nIts sides are ting\\u2019d with a resplendent glow,\\nThrough the dark robe oft amber rays prevail,\\nAnd like fair veins in sable marble flow;\\nStill warble, dying swan! still tell the tale,\\nThe enchanting tale, the tale of pleasing woe.\\n\\n"\n    },\n    "3": {\n        "Title": "\\u201cLa Belle Dame Sans Merci\\u201d",\n        "Poem": "O what can ail thee, knight-at-arms,Alone and palely loitering?The sedge has withered from the lake,And no birds sing.O what can ail thee, knight-at-arms,So haggard and so woe-begone?The squirrel\\u2019s granary is full,And the harvest\\u2019s done.",\n        "Poem_for_Human": "O what can ail thee, knight-at-arms,Alone and palely loitering?The sedge has withered from the lake,And no birds sing.O what can ail thee, knight-at-arms,So haggard and so woe-begone?The squirrel\\u2019s granary is full,And the harvest\\u2019s done."\n    },\n    "4": {\n        "Title": "Ode on Me ...

# %%
with open('/content/drive/MyDrive/NLP_ML/john_keats.txt', 'w') as outfile:
    json.dump(result_john, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
result_alfred = df_alfred.to_json(orient="index")
parsed_alfred = json.loads(result_alfred)
json.dumps(parsed_alfred, indent=4)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '{\n    "0": {\n        "Unnamed: 0": 0,\n        "Title": "The BlackBird",\n        "Poem": "The espaliers and the standards all Are thine; the range of lawn and park:The unnetted black-hearts ripen dark,All thine, against the garden wall.",\n        "Poem_for_Human": "O blackbird! sing me something well:\\nWhile all the neighbours shoot thee round,\\nI keep smooth plats of fruitful ground,\\nWhere thou may\'st warble, eat and dwell.\\n\\nThe espaliers and the standards all\\nAre thine; the range of lawn and park:\\nThe unnetted black-hearts ripen dark,\\nAll thine, against the garden wall.\\n\\nYet, tho\' I spared thee all the spring,\\nThy sole delight is, sitting still,\\nWith that gold dagger of thy bill\\nTo fret the summer jenneting.\\n"\n    },\n    "1": {\n        "Unnamed: 0": 1,\n        "Title": "The Deadth Of The Old Year ",\n        "Poem": "For the old year lies a-dying.Old year you must not die;You came to us so readily,You lived with us so steadily, Old year you shall not die.",\n        "Poem_for_Human": "Full knee-deep lies the winter snow,\\nAnd the winter winds are wearily sighing:\\nToll ye the church bell sad and slow,\\nAnd tread softly and speak low,\\nFor the old year lies a-dying.\\n       Old year you must not die;\\n       You came to us so readily,\\n       You lived with us so steadily,\\n       Old year you shall not die.\\n\\nHe lieth still: he doth not move:\\nHe will not see the dawn of day.\\nHe hath no other life above.\\nHe gave me a friend and a true truelove\\nAnd the New-year will take \'em away."\n    },\n    "2": {\n        "Unnamed: 0": 2,\n        "Title": "I Entreat You",\n        "Poem": "Good, but better when you share it.",\n        "Poem_for_Human": "I entreat you, Alfred Tennyson,\\nCome and share my haunch of venison.\\nI have too a bin of claret,\\nGood, but better when you share it.\\nTho\' \'tis only a small bin,\\nThere\'s a stock of it within.\\nAnd as sure as I\'m a rhymer,\\nHalf a butt of Rudeheimer.\\nCome; among the sons of men is one\\nWelcomer than Alfred Tennyson?"\n    },\n    "3": {\n        "Unnamed: 0": 3,\n        "Title": "Crossing The Bar ",\n        "Poem": "Sunset and evening star,And one clear call for me! And may there be no moaning of the bar,When I put out to sea,",\n        "Poem_for_Human": "Sunset and evening star,And one clear call for me! And may there be no moaning of the bar,When I put out to sea,"\n    },\n    "4": {\n        "Unnamed: 0": 4,\n        "Title": "The Brook",\n        "Poem": "I come from haunts of coot and hern,I make a sudden sallyAnd sparkle out among the fern,To bicker down a valley.",\n        "Poem_for_Human": "I come from haunts of coot and hern,I make a sudden sallyAnd sparkle out among the fern,To bicker down a valley."\n    },\n    "5": {\n        "Unnamed: 0": 5,\n        "Title": "Ode To Memory",\n        "Poem": "Come not as thou camest of late,Flinging the gloom of yesternight On the white day, but robed in soften\\u2019d light,Of orient state.",\n        "Poem_for_Human": null\n    },\n    "6": {\n        "Unnamed: 0": 6,\n        "Title": "Freedom",\n        "Poem": "Her open eyes desire the truth.The wisdom of a thousand years Is in them. May perpetual youth Keep dry their light from tears;",\n        "Poem_for_Human": "Of old sat Freedom on the heights,\\nThe thunders breaking at her feet:\\nAbove her shook the starry lights:\\nShe heard the torrents meet.\\n\\nThere in her place she did rejoice,\\nSelf-gather\'d in her prophet-mind,\\nBut fragments of her mighty voice\\nCame rolling on the wind.\\n"\n    },\n    "7": {\n        "Unnamed: 0": 7,\n        "Title": "The lady of Shalott",\n        "Poem": "Only reapers, reaping early In among the bearded barley,Hear a song that echoes cheerly From the river winding clearly,",\n        "Poem_for_Human": "Only reapers, reaping early\\nIn among the bearded barley,\\nHear a song that echoes cheerly\\nFrom the river winding clearly,\\nDown to tower\'d Camelot:\\nAnd by ...

# %%
with open('/content/drive/MyDrive/NLP_ML/alfred_tennyson.txt', 'w') as outfile:
    json.dump(result_alfred, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
parsed_alfred["0"]
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'Unnamed: 0': 0,
#  'Title': 'The BlackBird',
#  'Poem': 'The espaliers and the standards all Are thine; the range of lawn and park:The unnetted black-hearts ripen dark,All thine, against the garden wall.',
#  'Poem_for_Human': "O blackbird! sing me something well:\nWhile all the neighbours shoot thee round,\nI keep smooth plats of fruitful ground,\nWhere thou may'st warble, eat and dwell.\n\nThe espaliers and the standards all\nAre thine; the range of lawn and park:\nThe unnetted black-hearts ripen dark,\nAll thine, against the garden wall.\n\nYet, tho' I spared thee all the spring,\nThy sole delight is, sitting still,\nWith that gold dagger of thy bill\nTo fret the summer jenneting.\n"}

# %% [markdown]
# **Build JSON Structure**

# %%
john_keats = {

}

alfred_tennyson = {

}
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Data Cleaning**

# %%
def cleanPoemText(text):
    

    text = contractions.fix(text)
    
    text = text.strip().lower()
    
    text = re.sub(r"'", ' ', text)
    
    filters='!"\'#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n'
    translate_dict = dict((i, " ") for i in filters)
    translate_map = str.maketrans(translate_dict)
    text = text.translate(translate_map)

    text = ' '.join([w for w in text.split()])

    # Replace multiple space with one space
    text = re.sub(' +', ' ', text)
    
    text = ''.join(text)

    return text
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <>:10: DeprecationWarning: invalid escape sequence \]
# <>:10: DeprecationWarning: invalid escape sequence \]
# <ipython-input-19-ace87d021779>:10: DeprecationWarning: invalid escape sequence \]
#   filters='!"\'#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n'

# %% [markdown]
# **Clean Poem Text**

# %%
embedding = ''
def buildPoemArray(poet, data):
  poems = []
  for i in data:
    poem = data[i]["Poem"]

    clean_poem = cleanPoemText(poem)
    idx = "poem" + str(i)
    poet[idx] = clean_poem
    poems.append(idx)
  poet['poems_array'] = poems
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
buildPoemArray(alfred_tennyson, parsed_alfred)
buildPoemArray(john_keats, parsed)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
alfred_tennyson
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9']}

# %%
john_keats
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9']}

# %%
john_keats_poems = john_keats.copy()
alfred_tennyson_poems = alfred_tennyson.copy()
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Run Part-Of-Speech, extract verbs, nouns and adjectives**

# %%
def getPOS(poet):
  global_vrb= set()
  global_nns= set()
  global_adj= set()
  for key in poet['poems_array']:
    text = poet[key]
    wrd_list = word_tokenize(text)
    pos_val = nltk.pos_tag(wrd_list)
    poet["pos_"+key] = pos_val

    vrb = set([word for (word, pos) in pos_val if (pos.startswith('VB'))])
    nns = set([word for (word, pos) in pos_val if (pos.startswith('NN'))])
    adj = set([word for (word, pos) in pos_val if (pos.startswith('JJ'))])

    poet["verbs_"+key] = list(vrb)
    poet["adjectives_"+key] = list(adj)
    poet["nouns_"+key] = list(nns)

    global_vrb = set.union(global_vrb, vrb)
    global_nns = set.union(global_nns, nns)
    global_adj = set.union(global_adj, adj)

  poet['all_verbs'] = list(global_vrb)
  poet['all_nouns'] = list(global_nns)
  poet['all_adjectives'] = list(global_adj)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
alfred_tennyson_pos = alfred_tennyson.copy()
getPOS(alfred_tennyson_pos)
alfred_tennyson_pos
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9'],
#  'pos_poem0': [('the', 'DT'),
#   ('espaliers', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('standards', 'NNS'),
#   ('all', 'DT'),
#   ('are', 'VBP'),
#   ('thine', 'IN'),
#   ('the', 'DT'),
#   ('range', 'NN'),
#   ('of', 'IN'),
#   ('lawn', 'NN'),
#   ('and', 'CC'),
#   ('park', 'VB'),
#   ('the', 'DT'),
#   ('unnetted', 'JJ'),
#   ('black', 'JJ'),
#   ('hearts', 'NNS'),
#   ('ripen', 'VB'),
#   ('dark', 'NN'),
#   ('all', 'DT'),
#   ('thine', 'NN'),
#   ('against', 'IN'),
#   ('the', 'DT'),
#   ('garden', 'NN'),
#   ('wall', 'NN')],
#  'verbs_poem0': ['are', 'ripen', 'park'],
#  'adjectives_poem0': ['unnetted', 'black'],
#  'nouns_poem0': ['thine',
#   'espaliers',
#   'lawn',
#   'standards',
#   'hearts',
#   'garden',
#   'range',
#   'wall',
#   'dark'],
#  'pos_poem1': [('for', 'IN'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('year', 'NN'),
#   ('lies', 'VBZ'),
#   ('a', 'DT'),
#   ('dying', 'VBG'),
#   ('old', 'JJ'),
#   ('year', 'NN'),
#   ('you', 'PRP'),
#   ('must', 'MD'),
#   ('not', 'RB'),
#   ('die', 'VB'),
#   ('you', 'PRP'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('us', 'PRP'),
#   ('so', 'RB'),
#   ('readily', 'RB'),
#   ('you', 'PRP'),
#   ('lived', 'VBD'),
#   ('with', 'IN'),
#   ('us', 'PRP'),
#   ('so', 'RB'),
#   ('steadily', 'RB'),
#   ('old', 'JJ'),
#   ('year', 'NN'),
#   ('you', 'PRP'),
#   ('shall', 'MD'),
#   ('not', 'RB'),
#   ('die', 'VB')],
#  'verbs_poem1': ['lived', 'came', 'die', 'lies', 'dying'],
#  'adjectives_poem1': ['old'],
#  'nouns_poem1': ['year'],
#  'pos_poem2': [('good', 'JJ'),
#   ('but', 'CC'),
#   ('better', 'JJR'),
#   ('when', 'WRB'),
#   ('you', 'PRP'),
#   ('share', 'NN'),
#   ('it', 'PRP')],
#  'verbs_poem2': [],
#  'adjectives_poem2': ['good', 'better'],
#  'nouns_poem2': ['share'],
#  'pos_poem3': [('sunset', 'NN'),
#   ('and', 'CC'),
#   ('evening', 'VBG'),
#   ('star', 'NN'),
#   ('and', 'CC'),
#   ('one', 'CD'),
#   ('clear', 'JJ'),
#   ('call', 'NN'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('and', 'CC'),
#   ('may', 'MD'),
#   ('there', 'RB'),
#   ('be', 'VB'),
#   ('no', 'DT'),
#   ('moaning', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('bar', 'NN'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('put', 'VBD'),
#   ('out', 'RP'),
#   ('to', 'TO'),
#   ('sea', 'VB')],
#  'verbs_poem3': ['be', 'sea', 'put', 'evening'],
#  'adjectives_poem3': ['clear'],
#  'nouns_poem3': ['star', 'moaning', 'sunset', 'bar', 'call', 'i'],
#  'pos_poem4': [('i', 'JJ'),
#   ('come', 'VBP'),
#   ('from', 'IN'),
#   ('haunts', 'NNS'),
#   ('of', 'IN'),
#   ('coot', 'NN'),
#   ('and', 'CC'),
#   ('hern', 'JJ'),
#   ('i', 'NNS'),
#   ('make', 'VBP'),
#   ('a', 'DT'),
#   ('sudden', 'JJ'),
#   ('sallyand', 'NN'),
#   ('sparkle', 'VBZ'),
#   ('out', 'RP'),
#   ('among', 'IN'),
#   ('the', 'DT'),
#   ('fern', 'NN'),
#   ('to', 'TO'),
#   ('bicker', 'VB'),
#   ('down', 'RP'),
#   ('a', 'DT'),
#   ('valley', 'NN')],
#  'verbs_poem4': ['come', 'bicker', 'make', 'sparkle'],
#  'adjectives_poem4': ['hern', 'sudden', 'i'],
#  'nouns_poem4': ['haunts', 'coot', 'valley', 'sallyand', 'fern', 'i'],
#  'pos_poem5': [('come', 'RB'),
#   ('not', 'RB'),
#   ('as', 'IN'),
#   ('thou', 'JJ'),
#   ('camest', 'NN'),
#   ('of', 'IN'),
#   ('late', 'JJ'),
#   ('flinging', 'VBG'),
#   ('the', 'DT'),
#   ('gloom', 'NN'),
#   ('of', 'IN'),
#   ('yesternight', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('white', 'JJ'),
#   ('day', 'NN'),
#   ('but', 'CC'),
#   ('robed', 'VBD'),
#   ('in', 'IN'),
#   ('soften', 'JJ'),
#   ('’', 'NNP'),
#   ('d', 'NN'),
#   ('light', 'NN'),
#   ('of', 'IN'),
#   ('orient', 'JJ'),
#   ('state', 'NN')],
#  'verbs_poem5': ['flinging', 'robed'],
#  'adjectives_poem5': ['orient', 'white', 'thou', 'late', 'soften'],
#  'nouns_poem5': ['day',
#   'light',
#   'camest',
#   'state',
#   'gloom',
#   '’',
#   'd',
#   'yesternight'],
#  'pos_poem6': [('her', 'PRP$'),
#   ('open', 'JJ'),
#   ('eyes', 'NNS'),
#   ('desire', 'VBP'),
#   ('the', 'DT'),
#   ('truth', 'NN'),
#   ('the', 'DT'),
#   ('wisdom', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('thousand', 'CD'),
#   ('years', 'NNS'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('them', 'PRP'),
#   ('may', 'MD'),
#   ('perpetual', 'VB'),
#   ('youth', 'NN'),
#   ('keep', 'VB'),
#   ('dry', 'JJ'),
#   ('their', 'PRP$'),
#   ('light', 'NN'),
#   ('from', 'IN'),
#   ('tears', 'NNS')],
#  'verbs_poem6': ['desire', 'is', 'perpetual', 'keep'],
#  'adjectives_poem6': ['open', 'dry'],
#  'nouns_poem6': ['wisdom',
#   'years',
#   'tears',
#   'eyes',
#   'light',
#   'youth',
#   'truth'],
#  'pos_poem7': [('only', 'RB'),
#   ('reapers', 'NNS'),
#   ('reaping', 'VBG'),
#   ('early', 'JJ'),
#   ('in', 'IN'),
#   ('among', 'IN'),
#   ('the', 'DT'),
#   ('bearded', 'JJ'),
#   ('barley', 'NN'),
#   ('hear', 'VBP'),
#   ('a', 'DT'),
#   ('song', 'NN'),
#   ('that', 'WDT'),
#   ('echoes', 'VBZ'),
#   ('cheerly', 'RB'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('river', 'NN'),
#   ('winding', 'VBG'),
#   ('clearly', 'RB')],
#  'verbs_poem7': ['echoes', 'hear', 'reaping', 'winding'],
#  'adjectives_poem7': ['bearded', 'early'],
#  'nouns_poem7': ['barley', 'river', 'song', 'reapers'],
#  'pos_poem8': [('then', 'RB'),
#   ('might', 'MD'),
#   ('thy', 'VB'),
#   ('rays', 'NNS'),
#   ('pass', 'VB'),
#   ('thro', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   ('side', 'NN'),
#   ('so', 'RB'),
#   ('swiftly', 'RB'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('nowhere', 'RB'),
#   ('would', 'MD'),
#   ('abide', 'VB'),
#   ('but', 'CC'),
#   ('lose', 'VB'),
#   ('themselves', 'PRP'),
#   ('in', 'IN'),
#   ('utter', 'JJ'),
#   ('emptiness', 'NN')],
#  'verbs_poem8': ['thy', 'abide', 'lose', 'pass'],
#  'adjectives_poem8': ['utter', 'other'],
#  'nouns_poem8': ['thro', 'side', 'emptiness', 'rays'],
#  'pos_poem9': [('but', 'CC'),
#   ('while', 'IN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('were', 'VBD'),
#   ('sleeping', 'VBG'),
#   ('a', 'DT'),
#   ('full', 'JJ'),
#   ('tide', 'NN'),
#   ('rose', 'VBD'),
#   ('with', 'IN'),
#   ('ground', 'NN'),
#   ('swell', 'NN'),
#   ('which', 'WDT'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('foremost', 'NN'),
#   ('rocks', 'NNS'),
#   ('touching', 'VBG'),
#   ('upjetted', 'VBN'),
#   ('in', 'IN'),
#   ('spirts', 'NNS'),
#   ('of', 'IN'),
#   ('wild', 'JJ'),
#   ('sea', 'NN'),
#   ('smoke', 'NN'),
#   ('and', 'CC'),
#   ('scaled', 'VBN'),
#   ('in', 'IN'),
#   ('sheets', 'NNS'),
#   ('of', 'IN'),
#   ('wasteful', 'JJ'),
#   ('foam', 'NN'),
#   ('and', 'CC'),
#   ('fell', 'VBD')],
#  'verbs_poem9': ['sleeping',
#   'touching',
#   'were',
#   'fell',
#   'rose',
#   'scaled',
#   'upjetted'],
#  'adjectives_poem9': ['wasteful', 'full', 'wild'],
#  'nouns_poem9': ['sea',
#   'tide',
#   'ground',
#   'rocks',
#   'sheets',
#   'foam',
#   'smoke',
#   'spirts',
#   'swell',
#   'foremost'],
#  'all_verbs': ['sleeping',
#   'sea',
#   'came',
#   'scaled',
#   'ripen',
#   'keep',
#   'pass',
#   'thy',
#   'die',
#   'sparkle',
#   'flinging',
#   'were',
#   'put',
#   'lies',
#   'fell',
#   'rose',
#   'winding',
#   'dying',
#   'make',
#   'bicker',
#   'upjetted',
#   'lived',
#   'desire',
#   'is',
#   'echoes',
#   'touching',
#   'abide',
#   'hear',
#   'evening',
#   'park',
#   'robed',
#   'are',
#   'be',
#   'come',
#   'perpetual',
#   'reaping',
#   'lose'],
#  'all_nouns': ['sea',
#   'wisdom',
#   'eyes',
#   'hearts',
#   'camest',
#   'valley',
#   '’',
#   'yesternight',
#   'river',
#   'emptiness',
#   'thine',
#   'espaliers',
#   'tears',
#   'haunts',
#   'moaning',
#   'rocks',
#   'coot',
#   'range',
#   'smoke',
#   'wall',
#   'dark',
#   'call',
#   'spirts',
#   'swell',
#   'i',
#   'foremost',
#   'star',
#   'side',
#   'tide',
#   'lawn',
#   'sunset',
#   'bar',
#   'youth',
#   'state',
#   'thro',
#   'gloom',
#   'sallyand',
#   'd',
#   'fern',
#   'year',
#   'rays',
#   'day',
#   'years',
#   'standards',
#   'garden',
#   'light',
#   'reapers',
#   'ground',
#   'sheets',
#   'foam',
#   'share',
#   'barley',
#   'truth',
#   'song'],
#  'all_adjectives': ['orient',
#   'white',
#   'wild',
#   'open',
#   'unnetted',
#   'bearded',
#   'other',
#   'better',
#   'sudden',
#   'early',
#   'hern',
#   'old',
#   'wasteful',
#   'thou',
#   'utter',
#   'full',
#   'clear',
#   'black',
#   'dry',
#   'late',
#   'good',
#   'soften',
#   'i']}

# %%
alfred_tennyson
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9']}

# %%
john_keats_pos = john_keats.copy()
getPOS(john_keats_pos)
john_keats_pos
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9'],
#  'pos_poem0': [('pleasure', 'NN'),
#   ('never', 'RB'),
#   ('is', 'VBZ'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('touch', 'JJ'),
#   ('sweet', 'JJ'),
#   ('pleasure', 'NN'),
#   ('melteth', 'NNS'),
#   ('like', 'IN'),
#   ('to', 'TO'),
#   ('bubbles', 'NNS'),
#   ('when', 'WRB'),
#   ('rain', 'NN'),
#   ('pelteth', 'VBP'),
#   ('then', 'RB'),
#   ('let', 'VB'),
#   ('winged', 'JJ'),
#   ('fancy', 'JJ'),
#   ('wanderthrough', 'IN'),
#   ('the', 'DT'),
#   ('thought', 'NN'),
#   ('still', 'RB'),
#   ('spread', 'JJ'),
#   ('beyond', 'IN'),
#   ('her', 'PRP$'),
#   ('open', 'JJ'),
#   ('wide', 'JJ'),
#   ('the', 'DT'),
#   ('mind', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   ('cage', 'NN'),
#   ('door', 'NN'),
#   ('she', 'PRP'),
#   ('will', 'MD'),
#   ('dart', 'VB'),
#   ('forth', 'NN'),
#   ('and', 'CC'),
#   ('cloudward', 'NN'),
#   ('soar', 'NN')],
#  'verbs_poem0': ['let', 'dart', 'is', 'pelteth'],
#  'adjectives_poem0': ['fancy',
#   'open',
#   'wide',
#   'spread',
#   'winged',
#   'sweet',
#   'touch'],
#  'nouns_poem0': ['home',
#   '’',
#   'forth',
#   'pleasure',
#   'cloudward',
#   'thought',
#   's',
#   'soar',
#   'door',
#   'melteth',
#   'rain',
#   'bubbles',
#   'cage',
#   'mind'],
#  'pos_poem1': [('heard', 'NN'),
#   ('melodies', 'NNS'),
#   ('are', 'VBP'),
#   ('sweet', 'JJ'),
#   ('but', 'CC'),
#   ('those', 'DT'),
#   ('unheardare', 'JJ'),
#   ('sweeter', 'NN'),
#   ('therefore', 'RB'),
#   ('ye', 'JJ'),
#   ('soft', 'JJ'),
#   ('pipes', 'NNS'),
#   ('play', 'VBP'),
#   ('on', 'IN'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('sensual', 'JJ'),
#   ('ear', 'NN'),
#   ('but', 'CC'),
#   ('more', 'JJR'),
#   ('endear', 'JJ'),
#   ('’', 'NNP'),
#   ('d', 'NN'),
#   ('pipe', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('spirit', 'NN'),
#   ('ditties', 'NNS'),
#   ('of', 'IN'),
#   ('no', 'DT'),
#   ('tone', 'NN')],
#  'verbs_poem1': ['play', 'are'],
#  'adjectives_poem1': ['endear',
#   'more',
#   'ye',
#   'sensual',
#   'unheardare',
#   'sweet',
#   'soft'],
#  'nouns_poem1': ['spirit',
#   'ditties',
#   'tone',
#   'pipe',
#   'heard',
#   'pipes',
#   'melodies',
#   '’',
#   'd',
#   'ear',
#   'sweeter'],
#  'pos_poem2': [('byron', 'VB'),
#   ('how', 'WRB'),
#   ('sweetly', 'RB'),
#   ('sad', 'JJ'),
#   ('thy', 'NN'),
#   ('melody', 'NN'),
#   ('attuning', 'VBG'),
#   ('still', 'RB'),
#   ('the', 'DT'),
#   ('soul', 'NN'),
#   ('to', 'TO'),
#   ('tenderness', 'VB'),
#   ('as', 'IN'),
#   ('if', 'IN'),
#   ('soft', 'JJ'),
#   ('pity', 'NN'),
#   ('with', 'IN'),
#   ('unusual', 'JJ'),
#   ('stress', 'NN'),
#   ('had', 'VBD'),
#   ('touch', 'JJ'),
#   ('’', 'NNP'),
#   ('d', 'NN'),
#   ('her', 'PRP$'),
#   ('plaintive', 'JJ'),
#   ('lute', 'NN'),
#   ('and', 'CC'),
#   ('thou', 'NN'),
#   ('being', 'VBG'),
#   ('by', 'IN'),
#   ('hadst', 'NN'),
#   ('caught', 'VBD'),
#   ('the', 'DT'),
#   ('tones', 'NNS'),
#   ('nor', 'CC'),
#   ('suffer', 'VBP'),
#   ('’', 'NNP'),
#   ('d', 'VB'),
#   ('them', 'PRP'),
#   ('to', 'TO'),
#   ('die', 'VB')],
#  'verbs_poem2': ['tenderness',
#   'byron',
#   'being',
#   'had',
#   'suffer',
#   'die',
#   'attuning',
#   'd',
#   'caught'],
#  'adjectives_poem2': ['sad', 'unusual', 'plaintive', 'touch', 'soft'],
#  'nouns_poem2': ['stress',
#   'tones',
#   'thou',
#   'soul',
#   'thy',
#   'lute',
#   'pity',
#   '’',
#   'd',
#   'hadst',
#   'melody'],
#  'pos_poem3': [('o', 'IN'),
#   ('what', 'WP'),
#   ('can', 'MD'),
#   ('ail', 'VB'),
#   ('thee', 'VB'),
#   ('knight', 'NN'),
#   ('at', 'IN'),
#   ('arms', 'NNS'),
#   ('alone', 'RB'),
#   ('and', 'CC'),
#   ('palely', 'RB'),
#   ('loitering', 'VBG'),
#   ('the', 'DT'),
#   ('sedge', 'NN'),
#   ('has', 'VBZ'),
#   ('withered', 'VBN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('lake', 'NN'),
#   ('and', 'CC'),
#   ('no', 'DT'),
#   ('birds', 'NNS'),
#   ('sing', 'VBG'),
#   ('o', 'IN'),
#   ('what', 'WP'),
#   ('can', 'MD'),
#   ('ail', 'VB'),
#   ('thee', 'VB'),
#   ('knight', 'NN'),
#   ('at', 'IN'),
#   ('arms', 'NNS'),
#   ('so', 'RB'),
#   ('haggard', 'RB'),
#   ('and', 'CC'),
#   ('so', 'RB'),
#   ('woe', 'JJ'),
#   ('begone', 'NN'),
#   ('the', 'DT'),
#   ('squirrel', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   ('granary', 'NN'),
#   ('is', 'VBZ'),
#   ('full', 'JJ'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('harvest', 'NN'),
#   ('’', 'NN'),
#   ('s', 'NN'),
#   ('done', 'VBN')],
#  'verbs_poem3': ['is',
#   'done',
#   'ail',
#   'withered',
#   'sing',
#   'thee',
#   'has',
#   'loitering'],
#  'adjectives_poem3': ['full', 'woe'],
#  'nouns_poem3': ['granary',
#   'knight',
#   'arms',
#   'begone',
#   's',
#   'squirrel',
#   'sedge',
#   'harvest',
#   'lake',
#   'birds',
#   '’'],
#  'pos_poem4': [('no', 'DT'),
#   ('no', 'DT'),
#   ('go', 'VB'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('lethe', 'VB'),
#   ('neither', 'DT'),
#   ('twistwolf', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'VBZ'),
#   ('bane', 'NN'),
#   ('tight', 'NN'),
#   ('rooted', 'VBN'),
#   ('for', 'IN'),
#   ('its', 'PRP$'),
#   ('poisonous', 'JJ'),
#   ('wine', 'NN'),
#   ('nor', 'CC'),
#   ('suffer', 'NN'),
#   ('thy', 'JJ'),
#   ('pale', 'JJ'),
#   ('forehead', 'NN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('kiss', 'JJ'),
#   ('’', 'NNP'),
#   ('d', 'NN'),
#   ('by', 'IN'),
#   ('nightshade', 'JJ'),
#   ('ruby', 'NN'),
#   ('grape', 'NN'),
#   ('of', 'IN'),
#   ('proserpine', 'NN'),
#   ('make', 'VBP'),
#   ('not', 'RB'),
#   ('your', 'PRP$'),
#   ('rosary', 'NN'),
#   ('of', 'IN'),
#   ('yew', 'NN'),
#   ('berries', 'NNS'),
#   ('nor', 'CC'),
#   ('let', 'VB'),
#   ('the', 'DT'),
#   ('beetle', 'JJ'),
#   ('nor', 'CC'),
#   ('the', 'DT'),
#   ('death', 'NN'),
#   ('moth', 'NN'),
#   ('be', 'VB'),
#   ('your', 'PRP$'),
#   ('mournful', 'JJ'),
#   ('psyche', 'NN'),
#   ('nor', 'CC'),
#   ('the', 'DT'),
#   ('downy', 'JJ'),
#   ('owla', 'NN'),
#   ('partner', 'NN'),
#   ('in', 'IN'),
#   ('your', 'PRP$'),
#   ('sorrow', 'NN'),
#   ('’', 'NN'),
#   ('s', 'NN'),
#   ('mysteries', 'NNS'),
#   ('for', 'IN'),
#   ('shade', 'NN'),
#   ('to', 'TO'),
#   ('shade', 'VB'),
#   ('will', 'MD'),
#   ('come', 'VB'),
#   ('too', 'RB'),
#   ('drowsily', 'RB'),
#   ('and', 'CC'),
#   ('drown', 'VB'),
#   ('the', 'DT'),
#   ('wakeful', 'JJ'),
#   ('anguish', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('soul', 'NN')],
#  'verbs_poem4': ['drown',
#   'lethe',
#   's',
#   'shade',
#   'go',
#   'let',
#   'be',
#   'come',
#   'rooted',
#   'make'],
#  'adjectives_poem4': ['poisonous',
#   'pale',
#   'nightshade',
#   'kiss',
#   'beetle',
#   'thy',
#   'mournful',
#   'downy',
#   'wakeful'],
#  'nouns_poem4': ['moth',
#   'twistwolf',
#   'yew',
#   'psyche',
#   'tight',
#   'wine',
#   'owla',
#   '’',
#   'ruby',
#   'forehead',
#   'sorrow',
#   's',
#   'mysteries',
#   'death',
#   'proserpine',
#   'rosary',
#   'berries',
#   'shade',
#   'partner',
#   'anguish',
#   'suffer',
#   'd',
#   'bane',
#   'soul',
#   'grape'],
#  'pos_poem5': [('o', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('draught', 'NN'),
#   ('of', 'IN'),
#   ('vintage', 'NN'),
#   ('that', 'WDT'),
#   ('hath', 'VBD'),
#   ('been', 'VBN'),
#   ('cool', 'JJ'),
#   ('’', 'NNP'),
#   ('d', 'VBD'),
#   ('a', 'DT'),
#   ('long', 'JJ'),
#   ('age', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('deep', 'JJ'),
#   ('delved', 'VBD'),
#   ('earth', 'JJ'),
#   ('tasting', 'NN'),
#   ('of', 'IN'),
#   ('flora', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('country', 'NN'),
#   ('green', 'JJ'),
#   ('dance', 'NN'),
#   ('and', 'CC'),
#   ('provençal', 'NN'),
#   ('song', 'NN'),
#   ('and', 'CC'),
#   ('sunburnt', 'JJ'),
#   ('mirth', 'NN'),
#   ('o', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('beaker', 'NN'),
#   ('full', 'JJ'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('warm', 'JJ'),
#   ('south', 'NN')],
#  'verbs_poem5': ['delved', 'been', 'hath', 'd'],
#  'adjectives_poem5': ['cool',
#   'long',
#   'green',
#   'sunburnt',
#   'full',
#   'deep',
#   'earth',
#   'warm'],
#  'nouns_poem5': ['south',
#   'age',
#   'draught',
#   'provençal',
#   'beaker',
#   'tasting',
#   'dance',
#   'o',
#   'vintage',
#   'mirth',
#   '’',
#   'country',
#   'song',
#   'flora'],
#  'pos_poem6': [('o', 'JJ'),
#   ('soft', 'JJ'),
#   ('embalmer', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('still', 'RB'),
#   ('midnight', 'VBN'),
#   ('shutting', 'VBG'),
#   ('with', 'IN'),
#   ('careful', 'JJ'),
#   ('fingers', 'NNS'),
#   ('and', 'CC'),
#   ('benign', 'VB'),
#   ('our', 'PRP$'),
#   ('gloom', 'NN'),
#   ('pleas', 'NNS'),
#   ('’', 'VBP'),
#   ('d', 'JJ'),
#   ('eyes', 'NNS'),
#   ('embower', 'VBP'),
#   ('’', 'JJ'),
#   ('d', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('light', 'NN'),
#   ('enshaded', 'VBD'),
#   ('in', 'IN'),
#   ('forgetfulness', 'JJ'),
#   ('divine', 'NN'),
#   ('o', 'NN'),
#   ('soothest', 'JJS'),
#   ('sleep', 'NN'),
#   ('if', 'IN'),
#   ('so', 'IN'),
#   ('it', 'PRP'),
#   ('please', 'VB'),
#   ('thee', 'JJ'),
#   ('close', 'RB'),
#   ('in', 'IN'),
#   ('midst', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('thine', 'NN'),
#   ('hymn', 'NN'),
#   ('my', 'PRP$'),
#   ('willing', 'JJ'),
#   ('eyes', 'NNS'),
#   ('or', 'CC'),
#   ('wait', 'VB'),
#   ('the', 'DT'),
#   ('“', 'JJ'),
#   ('amen', 'NNS'),
#   ('”', 'VBP'),
#   ('ere', 'RB'),
#   ('thy', 'JJ'),
#   ('poppy', 'JJ'),
#   ('throws', 'NNS'),
#   ('around', 'IN'),
#   ('my', 'PRP$'),
#   ('bed', 'NN'),
#   ('its', 'PRP$'),
#   ('lulling', 'NN'),
#   ('charities', 'NNS')],
#  'verbs_poem6': ['please',
#   'benign',
#   '”',
#   'embower',
#   'shutting',
#   'midnight',
#   '’',
#   'enshaded',
#   'wait'],
#  'adjectives_poem6': ['soothest',
#   'poppy',
#   'careful',
#   '“',
#   'willing',
#   'thy',
#   'forgetfulness',
#   'o',
#   'thee',
#   '’',
#   'd',
#   'soft'],
#  'nouns_poem6': ['lulling',
#   'throws',
#   'divine',
#   'thine',
#   'midst',
#   'amen',
#   'bed',
#   'eyes',
#   'light',
#   'embalmer',
#   'charities',
#   'pleas',
#   'o',
#   'gloom',
#   'fingers',
#   'hymn',
#   'sleep',
#   'd'],
#  'pos_poem7': [('that', 'IN'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('not', 'RB'),
#   ('the', 'DT'),
#   ('cloudy', 'NN'),
#   ('winds', 'VBZ'),
#   ('to', 'TO'),
#   ('keep', 'VB'),
#   ('fresh', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('opening', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('morning', 'NN'),
#   ('’', 'NN'),
#   ('s', 'NN'),
#   ('eye', 'NN'),
#   ('such', 'JJ'),
#   ('dim', 'NN'),
#   ('conceived', 'VBD'),
#   ('glories', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('brain', 'NN'),
#   ('bring', 'NN'),
#   ('round', 'VBD'),
#   ('the', 'DT'),
#   ('heart', 'NN'),
#   ('an', 'DT'),
#   ('indescribable', 'JJ'),
#   ('feud', 'NN'),
#   ('so', 'RB'),
#   ('do', 'VB'),
#   ('these', 'DT'),
#   ('wonders', 'NNS'),
#   ('a', 'DT'),
#   ('most', 'RBS'),
#   ('dizzy', 'JJ'),
#   ('pain', 'NN'),
#   ('that', 'IN'),
#   ('mingles', 'VBZ'),
#   ('grecian', 'JJ'),
#   ('grandeur', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('rude', 'NN'),
#   ('wasting', 'NN'),
#   ('of', 'IN'),
#   ('old', 'JJ'),
#   ('time—with', 'NN'),
#   ('a', 'DT'),
#   ('billowy', 'NN'),
#   ('main—', 'NN'),
#   ('a', 'DT'),
#   ('sun—a', 'JJ'),
#   ('shadow', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('magnitude', 'NN')],
#  'verbs_poem7': ['winds',
#   'conceived',
#   'keep',
#   'mingles',
#   'round',
#   'do',
#   'have'],
#  'adjectives_poem7': ['sun—a',
#   'grecian',
#   'dizzy',
#   'such',
#   'indescribable',
#   'old'],
#  'nouns_poem7': ['billowy',
#   'time—with',
#   'opening',
#   'dim',
#   'rude',
#   '’',
#   'eye',
#   'wonders',
#   'feud',
#   'brain',
#   'pain',
#   's',
#   'heart',
#   'grandeur',
#   'bring',
#   'i',
#   'morning',
#   'cloudy',
#   'fresh',
#   'wasting',
#   'main—',
#   'magnitude',
#   'glories',
#   'shadow'],
#  'pos_poem8': [('where', 'WRB'),
#   ('are', 'VBP'),
#   ('the', 'DT'),
#   ('songs', 'NNS'),
#   ('of', 'IN'),
#   ('spring', 'NN'),
#   ('ay', 'NN'),
#   ('where', 'WRB'),
#   ('are', 'VBP'),
#   ('they', 'PRP'),
#   ('think', 'VBP'),
#   ('not', 'RB'),
#   ('of', 'IN'),
#   ('them', 'PRP'),
#   ('thou', 'VBP'),
#   ('hast', 'JJ'),
#   ('thy', 'JJ'),
#   ('music', 'NN'),
#   ('too', 'RB'),
#   ('—', 'NNP'),
#   ('while', 'IN'),
#   ('barred', 'VBN'),
#   ('clouds', 'NNS'),
#   ('bloom', 'IN'),
#   ('the', 'DT'),
#   ('soft', 'JJ'),
#   ('dying', 'NN'),
#   ('day', 'NN'),
#   ('and', 'CC'),
#   ('touch', 'VB'),
#   ('the', 'DT'),
#   ('stubble', 'JJ'),
#   ('plains', 'NNS'),
#   ('with', 'IN'),
#   ('rosy', 'JJ'),
#   ('hue', 'NNS'),
#   ('then', 'RB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('wailful', 'JJ'),
#   ('choir', 'NN'),
#   ('the', 'DT'),
#   ('small', 'JJ'),
#   ('gnats', 'NNS'),
#   ('mourn', 'VBP'),
#   ('among', 'IN'),
#   ('the', 'DT'),
#   ('river', 'NN'),
#   ('sallows', 'VBZ'),
#   ('borne', 'JJ'),
#   ('aloft', 'RB'),
#   ('or', 'CC'),
#   ('sinking', 'VBG'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('light', 'JJ'),
#   ('wind', 'NN'),
#   ('lives', 'VBZ'),
#   ('or', 'CC'),
#   ('dies', 'NNS'),
#   ('and', 'CC'),
#   ('full', 'JJ'),
#   ('grown', 'NN'),
#   ('lambs', 'NNS'),
#   ('loud', 'JJ'),
#   ('bleat', 'NN'),
#   ('from', 'IN'),
#   ('hilly', 'RB'),
#   ('bourn', 'VB'),
#   ('hedge', 'NN'),
#   ('crickets', 'NNS'),
#   ('sing', 'VBG'),
#   ('and', 'CC'),
#   ('now', 'RB'),
#   ('with', 'IN'),
#   ('treble', 'JJ'),
#   ('soft', 'JJ'),
#   ('the', 'DT'),
#   ('red', 'JJ'),
#   ('breast', 'NN'),
#   ('whistles', 'NNS'),
#   ('from', 'IN'),
#   ('a', 'DT'),
#   ('garden', 'NN'),
#   ('croft', 'NN'),
#   ('and', 'CC'),
#   ('gathering', 'NN'),
#   ('swallows', 'NNS'),
#   ('twitter', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('skies', 'NNS')],
#  'verbs_poem8': ['sallows',
#   'lives',
#   'thou',
#   'barred',
#   'sing',
#   'think',
#   'mourn',
#   'sinking',
#   'bourn',
#   'are',
#   'touch'],
#  'adjectives_poem8': ['stubble',
#   'wailful',
#   'hast',
#   'treble',
#   'borne',
#   'light',
#   'full',
#   'thy',
#   'small',
#   'loud',
#   'red',
#   'rosy',
#   'soft'],
#  'nouns_poem8': ['ay',
#   'songs',
#   'wind',
#   'dying',
#   'river',
#   'crickets',
#   'skies',
#   'lambs',
#   '—',
#   'spring',
#   'dies',
#   'gnats',
#   'plains',
#   'breast',
#   'gathering',
#   'whistles',
#   'clouds',
#   'choir',
#   'hedge',
#   'twitter',
#   'hue',
#   'bleat',
#   'swallows',
#   'day',
#   'croft',
#   'garden',
#   'music',
#   'grown'],
#  'pos_poem9': [('bright', 'JJ'),
#   ('star', 'NN'),
#   ('would', 'MD'),
#   ('i', 'VB'),
#   ('were', 'VBD'),
#   ('stedfast', 'VBN'),
#   ('as', 'IN'),
#   ('thou', 'NN'),
#   ('art—', 'IN'),
#   ('not', 'RB'),
#   ('in', 'IN'),
#   ('lone', 'JJ'),
#   ('splendour', 'NN'),
#   ('hung', 'NN'),
#   ('aloft', 'RB'),
#   ('the', 'DT'),
#   ('night', 'NN'),
#   ('and', 'CC'),
#   ('watching', 'VBG'),
#   ('with', 'IN'),
#   ('eternal', 'JJ'),
#   ('lids', 'NNS'),
#   ('apart', 'RB'),
#   ('like', 'IN'),
#   ('nature', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   ('patient', 'NN'),
#   ('sleepless', 'NN'),
#   ('eremite', 'VBP'),
#   ('the', 'DT'),
#   ('moving', 'VBG'),
#   ('waters', 'NNS'),
#   ('at', 'IN'),
#   ('their', 'PRP$'),
#   ('priestlike', 'NN'),
#   ('task', 'NN')],
#  'verbs_poem9': ['eremite', 'moving', 'watching', 'were', 'stedfast', 'i'],
#  'adjectives_poem9': ['bright', 'lone', 'eternal'],
#  'nouns_poem9': ['star',
#   'patient',
#   'priestlike',
#   'task',
#   'thou',
#   's',
#   'lids',
#   'splendour',
#   'sleepless',
#   'waters',
#   'nature',
#   '’',
#   'night',
#   'hung'],
#  'all_verbs': ['byron',
#   'delved',
#   'watching',
#   'play',
#   'sinking',
#   'has',
#   'bourn',
#   '’',
#   'wait',
#   'rooted',
#   'loitering',
#   'have',
#   'make',
#   'please',
#   'hath',
#   'is',
#   'winds',
#   'moving',
#   'conceived',
#   'being',
#   'lethe',
#   's',
#   'midnight',
#   'mingles',
#   'had',
#   'withered',
#   'stedfast',
#   'be',
#   'come',
#   'are',
#   'enshaded',
#   'caught',
#   'i',
#   'been',
#   'eremite',
#   'tenderness',
#   'sallows',
#   'benign',
#   'done',
#   'shutting',
#   'shade',
#   'go',
#   'keep',
#   'die',
#   'dart',
#   'round',
#   'thee',
#   'do',
#   'suffer',
#   'barred',
#   'were',
#   'd',
#   'think',
#   'mourn',
#   'touch',
#   'drown',
#   '”',
#   'lives',
#   'thou',
#   'embower',
#   'ail',
#   'let',
#   'sing',
#   'pelteth',
#   'attuning'],
#  'all_nouns': ['time—with',
#   'wind',
#   'lids',
#   'thy',
#   'eye',
#   'amen',
#   'squirrel',
#   'embalmer',
#   'charities',
#   'skies',
#   'lambs',
#   'death',
#   'fingers',
#   'rain',
#   'bubbles',
#   'star',
#   'task',
#   'breast',
#   'shade',
#   'heard',
#   'sweeter',
#   'glories',
#   'day',
#   'thou',
#   'soul',
#   'harvest',
#   'nature',
#   'birds',
#   'grown',
#   'ay',
#   'songs',
#   'priestlike',
#   'twistwolf',
#   'dim',
#   'tight',
#   'eyes',
#   'rude',
#   'tasting',
#   '’',
#   'flora',
#   'knight',
#   'forehead',
#   'sorrow',
#   'pleasure',
#   's',
#   'heart',
#   'waters',
#   'mirth',
#   'bed',
#   'cage',
#   'i',
#   'proserpine',
#   'morning',
#   'fresh',
#   'plains',
#   'sedge',
#   'main—',
#   'gathering',
#   'd',
#   'whistles',
#   'hedge',
#   'bane',
#   'forth',
#   'bleat',
#   'light',
#   'ditties',
#   'soar',
#   'melteth',
#   'music',
#   'country',
#   'ear',
#   'cloudward',
#   'home',
#   'billowy',
#   'moth',
#   'yew',
#   'psyche',
#   'pleas',
#   'splendour',
#   'wine',
#   'dance',
#   'vintage',
#   'pipe',
#   'wonders',
#   'hadst',
#   'feud',
#   'hung',
#   'ruby',
#   'brain',
#   'tones',
#   'spirit',
#   'pain',
#   'spring',
#   'dies',
#   'granary',
#   'arms',
#   'rosary',
#   'midst',
#   'thought',
#   'wasting',
#   'partner',
#   'lute',
#   'pity',
#   'hymn',
#   'clouds',
#   'choir',
#   'twitter',
#   'swallows',
#   'draught',
#   'shadow',
#   'croft',
#   'garden',
#   'grape',
#   'beaker',
#   'mind',
#   'age',
#   'opening',
#   'provençal',
#   'owla',
#   'lake',
#   'melodies',
#   'dying',
#   'lulling',
#   'river',
#   'crickets',
#   'divine',
#   'thine',
#   'mysteries',
#   'tone',
#   'o',
#   '—',
#   'sleep',
#   'door',
#   'grandeur',
#   'night',
#   'bring',
#   'melody',
#   'gnats',
#   'south',
#   'patient',
#   'berries',
#   'cloudy',
#   'anguish',
#   'gloom',
#   'suffer',
#   'magnitude',
#   'throws',
#   'begone',
#   'hue',
#   'stress',
#   'sleepless',
#   'pipes',
#   'song'],
#  'all_adjectives': ['fancy',
#   'soothest',
#   'stubble',
#   'nightshade',
#   'open',
#   'green',
#   'kiss',
#   'thy',
#   'deep',
#   'grecian',
#   'ye',
#   '’',
#   'indescribable',
#   'soft',
#   'lone',
#   'careful',
#   'sensual',
#   'unusual',
#   'full',
#   'wide',
#   'beetle',
#   'woe',
#   'treble',
#   'borne',
#   'downy',
#   'o',
#   'more',
#   'plaintive',
#   'rosy',
#   'wakeful',
#   'poisonous',
#   'pale',
#   'long',
#   'poppy',
#   'wailful',
#   'eternal',
#   'hast',
#   'forgetfulness',
#   'thee',
#   'loud',
#   'red',
#   'endear',
#   'd',
#   'warm',
#   'such',
#   'touch',
#   'old',
#   'cool',
#   'sad',
#   '“',
#   'sunburnt',
#   'willing',
#   'light',
#   'sun—a',
#   'earth',
#   'mournful',
#   'small',
#   'winged',
#   'dizzy',
#   'unheardare',
#   'sweet',
#   'bright',
#   'spread']}

# %%
john_keats
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9']}

# %% [markdown]
# **Store the POS JSON Data to File**

# %%
with open('/content/drive/MyDrive/NLP_ML/john_keats.json', 'w') as outfile:
    json.dump(john_keats_pos, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
with open('/content/drive/MyDrive/NLP_ML/alfred_tennyson.json', 'w') as outfile:
    json.dump(alfred_tennyson_pos, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Summarization using transformers**

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
summarizer = pipeline("summarization", model="t5-base", tokenizer="t5-base", framework="tf")
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/892M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
def getSummaryOfPoem(poet):
  def removeQuotes(mydata):
    new_data = mydata.strip('“”')
    return new_data
  count = 0
  for key in poet['poems_array']:
    count += 1;
    text = poet[key] 
    text = removeQuotes(text)
    summary_text = summarizer(text, max_length=512, min_length=5, do_sample=False)[0]['summary_text']
    poet["summary_"+key] = summary_text
  
  return poet
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from time import gmtime, strftime
print (strftime("%Y-%m-%d %H:%M:%S", gmtime()))

from time import gmtime, strftime
print (strftime("%Y-%m-%d %H:%M:%S", gmtime()))

import timeit

start = timeit.default_timer()
# Out:
# 2023-04-11 01:05:07
# 2023-04-11 01:05:07
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
john_keats_sum = john_keats.copy()
alfred_tennyson_sum = alfred_tennyson.copy()
data_john_keats = getSummaryOfPoem(john_keats_sum)
data_alfred_tennyson = getSummaryOfPoem(alfred_tennyson_sum)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Your max_length is set to 512, but you input_length is only 58. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# /usr/local/lib/python3.9/dist-packages/transformers/generation/tf_utils.py:745: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Your max_length is set to 512, but you input_length is only 48. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 512, but you input_length is only 63. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 512, but you input_length is only 73. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 512, but you input_length is only 118. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 512, but you input_length is only 68. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 512, but you input_length is only 98. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 512, but you input_length is only 94. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 512, but you input_length is only 136. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 512, but you input_length is only 58. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 512, but you input_length is only 37. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 512, but you input_length is only 36. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 512, but you input_length is only 10. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
# Your max_length is set to 512, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 512, but you input_length is only 39. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 512, but you input_length is only 44. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 512, but you input_length is only 28. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Your max_length is set to 512, but you input_length is only 33. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 512, but you input_length is only 36. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 512, but you input_length is only 49. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)

# %%
#Your statements here

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# Time:  709.6815052489999
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_alfred_tennyson
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9'],
#  'summary_poem0': 'espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall .',
#  'summary_poem1': 'old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old yearyou shall not die .',
#  'summary_poem2': 'good but better when you share it with others .',
#  'summary_poem3': 'sunset and evening star and one clear call for me . may there be no moaning of the bar when i put out to sea .',
#  'summary_poem4': "cnn's jim boulden comes from haunts of coot and hern . he makes a sudden sallyand sparkle out among the fern to bicker down a valley .",
#  'summary_poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state .',
#  'summary_poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears .',
#  'summary_poem7': 'only reapers reap early in among the bearded barley hear a song that echoes cheerily from the river winding clearly .',
#  'summary_poem8': 'thy rays might pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness .',
#  'summary_poem9': 'a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam .'}

# %%
alfred_tennyson_sum
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9'],
#  'summary_poem0': 'espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall .',
#  'summary_poem1': 'old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old yearyou shall not die .',
#  'summary_poem2': 'good but better when you share it with others .',
#  'summary_poem3': 'sunset and evening star and one clear call for me . may there be no moaning of the bar when i put out to sea .',
#  'summary_poem4': "cnn's jim boulden comes from haunts of coot and hern . he makes a sudden sallyand sparkle out among the fern to bicker down a valley .",
#  'summary_poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state .',
#  'summary_poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears .',
#  'summary_poem7': 'only reapers reap early in among the bearded barley hear a song that echoes cheerily from the river winding clearly .',
#  'summary_poem8': 'thy rays might pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness .',
#  'summary_poem9': 'a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam .'}

# %%
john_keats_sum
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  'poems_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9'],
#  'summary_poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar .',
#  'summary_poem1': 'ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone .',
#  'summary_poem2': 'melody attuned still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die .',
#  'summary_poem3': 'what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing . the squirrel’s granary is full and the harvest’s done .',
#  'summary_poem4': 'twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kissed by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche .',
#  'summary_poem5': 'vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south .',
#  'summary_poem6': "o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close inmidst of this thine hymn my willing eyes or wait the 'amen' ere thy poppy throws around my bed its lulling charities .",
#  'summary_poem7': 'i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time .',
#  'summary_poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too . barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies .',
#  'summary_poem9': 'not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task .'}

# %% [markdown]
# **Store the summarized JSON Data to File**

# %%
with open('/content/drive/MyDrive/NLP_ML/john_keats.json', 'w') as outfile:
    json.dump(john_keats_sum, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
with open('/content/drive/MyDrive/NLP_ML/alfred_tennyson.json', 'w') as outfile:
    json.dump(alfred_tennyson_sum, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Interchange the Verbs and Adjectives for both the poets using transformer**

# %%
model = SentenceTransformer('stsb-roberta-large')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Downloading (…)e63b6/.gitattributes:   0%|          | 0.00/748 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# Downloading (…)677c5e63b6/README.md:   0%|          | 0.00/3.92k [00:00<?, ?B/s]
# Downloading (…)b6/added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)7c5e63b6/config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading (…)77c5e63b6/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)e63b6/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading (…)77c5e63b6/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)c5e63b6/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
def getSemanticSimilarity(p1,p2):
  embedding1 = model.encode(p1, convert_to_tensor=True)
  embedding2 = model.encode(p2, convert_to_tensor=True)
  cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
  print(cosine_scores) 
  similarity_score = cosine_scores.item()
  return similarity_score
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
getSemanticSimilarity(john_keats_pos['all_verbs'][0],alfred_tennyson_pos["all_verbs"][0])
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tensor([[0.0468]])
# 0.04682961478829384

# %% [markdown]
# **Swapping the Verbs based on similarity score**

# %%
def swapVerbs(p1,p2,text):
    for v1 in p1:
      for v2 in p2:
        score = getSemanticSimilarity(v1,v2)
        if score > 0.3:
          text = text.replace(v1,v2)
          print("verb")
          print(text)
          break
    return text
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
#  Swapping the Adjectives based on similarity score

# %%
def swapAdjectives(p1,p2, poem):
  text = poem
  for a1 in p1:
    for a2 in p2:
      print("inside loop 2")
      print(a1)
      print(a2)
      print(text)
      score = getSemanticSimilarity(a1,a2)
      if score > 0.3:
        text = text.replace(a1,a2)
        print("adjective")
        print(text)
  return text
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def swapIteration(poet1, poet2, text):
    p2_verbs = poet2["all_verbs"]
    p1_verbs = poet1["all_verbs"]
    p2_verbs = p2_verbs[0:2]
    p1_verbs = p1_verbs[0:2]
    print(p1_verbs)
    print(p2_verbs)
    new_text = swapVerbs(p1_verbs, p2_verbs, text)
    print("new text verbs")
    print(new_text)
    # print(text)
    p2_adjectives = poet2["all_adjectives"]
    p1_adjectives = poet1["all_adjectives"]
    p2_adjectives = p2_adjectives[0:2]
    p1_adjectives = p1_adjectives[0:2]
    brand_new_text = swapAdjectives(p1_adjectives, p2_adjectives, new_text)
    print("new text adjectives")
    print(brand_new_text)
    return brand_new_text
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **John Poems Swapped Verbs and Adjectives of Alfred Tennyson Poems**

# %%
john_keats_poems_2 = john_keats_poems.copy()
john_keats_poems_2.pop('poems_array')
john_keats_poems_swapped=[]
for i in john_keats_poems:
  print("poems:")
  print(i)
  # inx = 'poem'+str(i);
  poem_str = str(john_keats_poems[i]);
  print(poem_str)

  john_keats_poems_swapped.append(swapIteration(john_keats_pos, alfred_tennyson_pos, poem_str))
# Out:
# poems:
# poem0
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# ['byron', 'delved']
# ['sleeping', 'sea']
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# inside loop 2
# fancy
# orient
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# tensor([[0.0190]])
# new text adjectives
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# poems:
# poem1
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# inside loop 2
# fancy
# orient
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# tensor([[0.0190]])
# new text adjectives
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# poems:
# poem2
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# inside loop 2
# fancy
# orient
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# tensor([[0.0190]])
# new text adjectives
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# poems:
# poem3
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# inside loop 2
# fancy
# orient
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# tensor([[0.0190]])
# new text adjectives
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# poems:
# poem4
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# inside loop 2
# fancy
# orient
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# tensor([[0.0190]])
# new text adjectives
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# poems:
# poem5
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# inside loop 2
# fancy
# orient
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# tensor([[0.0190]])
# new text adjectives
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# poems:
# poem6
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# inside loop 2
# fancy
# orient
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# tensor([[0.0190]])
# new text adjectives
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# poems:
# poem7
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# inside loop 2
# fancy
# orient
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# tensor([[0.0190]])
# new text adjectives
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# poems:
# poem8
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# inside loop 2
# fancy
# orient
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# tensor([[0.0190]])
# new text adjectives
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# poems:
# poem9
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# inside loop 2
# fancy
# orient
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# tensor([[0.0190]])
# new text adjectives
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# poems:
# poems_array
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# inside loop 2
# fancy
# orient
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.0190]])
# new text adjectives
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']

# %% [markdown]
# **Printing the new poems after swapping**

# %%
john_keats_poems_swapped
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']"]

# %% [markdown]
# **TODO: We need to format the poem in a human readable manner**

# %%
alfred_tennyson_poems_swapped = []
alfred_tennyson_poems_2 = alfred_tennyson_poems.copy()
alfred_tennyson_poems_2.pop('poems_array')
for i in alfred_tennyson_poems:
  print("poems:")
  print(i)
  # inx = 'poem'+str(i);
  poem_str_2 = str(alfred_tennyson_poems[i]);
  print(poem_str_2)

  alfred_tennyson_poems_swapped.append(swapIteration(john_keats_pos, alfred_tennyson_pos, poem_str_2))
# Out:
# poems:
# poem0
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# ['byron', 'delved']
# ['sleeping', 'sea']
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# inside loop 2
# fancy
# orient
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# tensor([[0.0190]])
# new text adjectives
# the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall
# poems:
# poem1
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# inside loop 2
# fancy
# orient
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# tensor([[0.0190]])
# new text adjectives
# for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die
# poems:
# poem2
# good but better when you share it
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# good but better when you share it
# inside loop 2
# fancy
# orient
# good but better when you share it
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# good but better when you share it
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# good but better when you share it
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# good but better when you share it
# tensor([[0.0190]])
# new text adjectives
# good but better when you share it
# poems:
# poem3
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# inside loop 2
# fancy
# orient
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# tensor([[0.0190]])
# new text adjectives
# sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea
# poems:
# poem4
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# inside loop 2
# fancy
# orient
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# tensor([[0.0190]])
# new text adjectives
# i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley
# poems:
# poem5
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# inside loop 2
# fancy
# orient
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# tensor([[0.0190]])
# new text adjectives
# come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state
# poems:
# poem6
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# inside loop 2
# fancy
# orient
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# tensor([[0.0190]])
# new text adjectives
# her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears
# poems:
# poem7
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# inside loop 2
# fancy
# orient
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# tensor([[0.0190]])
# new text adjectives
# only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly
# poems:
# poem8
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# inside loop 2
# fancy
# orient
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# tensor([[0.0190]])
# new text adjectives
# then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness
# poems:
# poem9
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# inside loop 2
# fancy
# orient
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# tensor([[0.0190]])
# new text adjectives
# but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell
# poems:
# poems_array
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# ['byron', 'delved']
# ['sleeping', 'sea']
# tensor([[0.0468]])
# tensor([[0.1364]])
# tensor([[0.1811]])
# tensor([[0.1595]])
# new text verbs
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# inside loop 2
# fancy
# orient
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.2333]])
# inside loop 2
# fancy
# white
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.2143]])
# inside loop 2
# soothest
# orient
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.2846]])
# inside loop 2
# soothest
# white
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']
# tensor([[0.0190]])
# new text adjectives
# ['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']

# %% [markdown]
# **Printing the new poems after swapping**

# %%
alfred_tennyson_poems_swapped
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'good but better when you share it',
#  'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']"]

# %% [markdown]
# **Swapped Poem**

# %%
def buildSwappedPoemArray(poet,data):
  poems = []
  data_length = len(data)
  for i in range(data_length):
    poem = data[i]
    #clean_poem = cleanPoemText(poem)
    idx = "poem" + str(i)
    poet[idx] = poem
    poems.append(idx)
  poet['poems_swapped_array'] = poems
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
john_keats_swapped = {

}

alfred_tennyson_swapped = {

}
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
john_keats_poems_swapped
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']"]

# %%
buildSwappedPoemArray(john_keats_swapped,john_keats_poems_swapped)
buildSwappedPoemArray(alfred_tennyson_swapped,alfred_tennyson_poems_swapped)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
john_keats_swapped
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  'poem10': "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']",
#  'poems_swapped_array': ['poem0',
#   'poem1',
#   'poem2',
#   'poem3',
#   'poem4',
#   'poem5',
#   'poem6',
#   'poem7',
#   'poem8',
#   'poem9',
#   'poem10']}

# %%
john_keats_swapped_to_json_file = john_keats_swapped.copy()
john_keats_swapped_to_json_file.pop('poems_swapped_array')
john_keats_swapped_to_json_file.pop('poem10')

alfred_tennyson_swapped_to_json_file = alfred_tennyson_swapped.copy()
alfred_tennyson_swapped_to_json_file.pop('poems_swapped_array')
alfred_tennyson_swapped_to_json_file.pop('poem10')
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']"

# %%
john_keats_swapped_to_json_file
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task'}

# %%
alfred_tennyson_swapped_to_json_file
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell'}

# %%
with open('/content/drive/MyDrive/NLP_ML/afterswap_john_keats.json', 'w') as outfile:
    json.dump(john_keats_swapped_to_json_file, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
with open('/content/drive/MyDrive/NLP_ML/alfred_tennysonafterswap.json', 'w') as outfile:
    json.dump(alfred_tennyson_swapped_to_json_file, outfile)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.9/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
john_keats_choherence_input = john_keats.copy()
john_keats_choherence_input.pop('poems_array')
john_keats_choherence_input
# Out:
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task'}

# %%
swapped_john_keats_choherence_input = john_keats_swapped.copy()
swapped_john_keats_choherence_input.pop('poems_swapped_array')
swapped_john_keats_choherence_input
# Out:
# {'poem0': 'pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar',
#  'poem1': 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone',
#  'poem2': 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die',
#  'poem3': 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done',
#  'poem4': 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul',
#  'poem5': 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south',
#  'poem6': 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities',
#  'poem7': 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude',
#  'poem8': 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies',
#  'poem9': 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task',
#  'poem10': "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']"}

# %%
coherence_perplexity_calculator = alfred_tennyson.copy()
coherence_perplexity_calculator.pop('poems_array')
coherence_perplexity_calculator
# Out:
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell'}

# %%
swapped_coherence_perplexity_calculator = alfred_tennyson_swapped.copy()
swapped_coherence_perplexity_calculator.pop('poems_swapped_array')
swapped_coherence_perplexity_calculator
# Out:
# {'poem0': 'the espaliers and the standards all are thine the range of lawn and park the unnetted black hearts ripen dark all thine against the garden wall',
#  'poem1': 'for the old year lies a dying old year you must not die you came to us so readily you lived with us so steadily old year you shall not die',
#  'poem2': 'good but better when you share it',
#  'poem3': 'sunset and evening star and one clear call for me and may there be no moaning of the bar when i put out to sea',
#  'poem4': 'i come from haunts of coot and hern i make a sudden sallyand sparkle out among the fern to bicker down a valley',
#  'poem5': 'come not as thou camest of late flinging the gloom of yesternight on the white day but robed in soften’d light of orient state',
#  'poem6': 'her open eyes desire the truth the wisdom of a thousand years is in them may perpetual youth keep dry their light from tears',
#  'poem7': 'only reapers reaping early in among the bearded barley hear a song that echoes cheerly from the river winding clearly',
#  'poem8': 'then might thy rays pass thro to the other side so swiftly that they nowhere would abide but lose themselves in utter emptiness',
#  'poem9': 'but while the two were sleeping a full tide rose with ground swell which on the foremost rocks touching upjetted in spirts of wild sea smoke and scaled in sheets of wasteful foam and fell',
#  'poem10': "['poem0', 'poem1', 'poem2', 'poem3', 'poem4', 'poem5', 'poem6', 'poem7', 'poem8', 'poem9']"}

# %%
# !pip install -upgrade gensim
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -u

# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.9/dist-packages (3.4.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (4.3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (67.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.9.3)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.22.4)
# Requirement already satisfied: funcy in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.2.2)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.4.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.4->pyLDAvis) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.4->pyLDAvis) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->pyLDAvis) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->pyLDAvis) (1.16.0)

# %%
poem_count = len(john_keats_choherence_input)
john_poem_list=[]
for j in john_keats_choherence_input:
  poem_index =  str(j)
  print(poem_index)
  print(john_keats_choherence_input[poem_index])
  john_poem_list.append(john_keats_choherence_input[poem_index])
print(john_poem_list)
# Out:
# poem0
# pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar
# poem1
# heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone
# poem2
# byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die
# poem3
# o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done
# poem4
# no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul
# poem5
# o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south
# poem6
# o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities
# poem7
# that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude
# poem8
# where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies
# poem9
# bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task
# ['pleasure never is at home at a touch sweet pleasure melteth like to bubbles when rain pelteth then let winged fancy wanderthrough the thought still spread beyond her open wide the mind’s cage door she will dart forth and cloudward soar', 'heard melodies are sweet but those unheardare sweeter therefore ye soft pipes play on not to the sensual ear but more endear’d pipe to the spirit ditties of no tone', 'byron how sweetly sad thy melody attuning still the soul to tenderness as if soft pity with unusual stress had touch’d her plaintive lute and thou being by hadst caught the tones nor suffer’d them to die', 'o what can ail thee knight at arms alone and palely loitering the sedge has withered from the lake and no birds sing o what can ail thee knight at arms so haggard and so woe begone the squirrel’s granary is full and the harvest’s done', 'no no go not to lethe neither twistwolf’s bane tight rooted for its poisonous wine nor suffer thy pale forehead to be kiss’d by nightshade ruby grape of proserpine make not your rosary of yew berries nor let the beetle nor the death moth be your mournful psyche nor the downy owla partner in your sorrow’s mysteries for shade to shade will come too drowsily and drown the wakeful anguish of the soul', 'o for a draught of vintage that hath been cool’d a long age in the deep delved earth tasting of flora and the country green dance and provençal song and sunburnt mirth o for a beaker full of the warm south', 'o soft embalmer of the still midnight shutting with careful fingers and benign our gloom pleas’d eyes embower’d from the light enshaded in forgetfulness divine o soothest sleep if so it please thee close in midst of this thine hymn my willing eyes or wait the “amen ” ere thy poppy throws around my bed its lulling charities', 'that i have not the cloudy winds to keep fresh for the opening of the morning’s eye such dim conceived glories of the brain bring round the heart an indescribable feud so do these wonders a most dizzy pain that mingles grecian grandeur with the rude wasting of old time—with a billowy main— a sun—a shadow of a magnitude', 'where are the songs of spring ay where are they think not of them thou hast thy music too — while barred clouds bloom the soft dying day and touch the stubble plains with rosy hue then in a wailful choir the small gnats mourn among the river sallows borne aloft or sinking as the light wind lives or dies and full grown lambs loud bleat from hilly bourn hedge crickets sing and now with treble soft the red breast whistles from a garden croft and gathering swallows twitter in the skies', 'bright star would i were stedfast as thou art— not in lone splendour hung aloft the night and watching with eternal lids apart like nature’s patient sleepless eremite the moving waters at their priestlike task']

# %% [markdown]
# **Original John Keats Poem's perplexity and coherence score**

# %%
# !pip install attrs==19.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting attrs==19.1.0
#   Downloading attrs-19.1.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# visions 0.7.5 requires attrs>=19.3.0, but you have attrs 19.1.0 which is incompatible.
# pytest 7.2.2 requires attrs>=19.2.0, but you have attrs 19.1.0 which is incompatible.
# Successfully installed attrs-19.1.0

# %%
# !pip install pandas --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Collecting pandas
#   Downloading pandas-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 52.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.1.2 requires pandas!=1.4.0,<1.6,>1.1, but you have pandas 2.0.0 which is incompatible.
# visions 0.7.5 requires attrs>=19.3.0, but you have attrs 19.1.0 which is incompatible.
# Successfully installed pandas-2.0.0
